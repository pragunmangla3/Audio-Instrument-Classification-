# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install python_speech_features
# Out:
# Requirement already satisfied: python_speech_features in /usr/local/lib/python3.6/dist-packages (0.6)

# %%
import os
from scipy.io import wavfile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Conv2D , MaxPool2D , Flatten , LSTM
from keras.layers import Dropout , Dense , TimeDistributed
from keras.models import Sequential
from keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
from tqdm import tqdm
from python_speech_features import mfcc
import pickle
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# # New Section

# %%
data = pd.read_csv("/content/drive/My Drive/Colab Notebooks/instrumentals.csv") 
df = data.copy()
df.set_index("fname", inplace = True)
df.describe()
# Out:
#         label
# count    2480
# unique     10
# top     Cello
# freq      297

# %%
for f in df.index :
    rate , signal = wavfile.read('/content/drive/My Drive/Colab Notebooks/cleaner/'+f)
    df.at[f , 'length'] = (signal.shape[0]/rate)

# %%
classes = list(np.unique(df.label)) # all the unique_classes
class_dist = df.groupby(['label'])['length'].mean()

# %%
fig, ax = plt.subplots()
ax.set_title('Class Distribution' , y =1.08 )
ax.pie(class_dist, labels = class_dist.index , autopct ='%1.1f%%',shadow = False,startangle = 90)
ax.axis('equal')
plt.show()  # class imbalance can be clearly seen, collecting more data or dropping some data is not feasable in real world
df
# Out:
#                         label     length
# fname
# 00044347.wav           Hi-hat  10.598375
# 001ca53d.wav        Saxophone  10.013438
# 00353774.wav            Cello   4.520000
# 003b91e8.wav            Cello  13.280000
# 004ad66f.wav         Clarinet   6.654063
# ...                       ...        ...
# ff3f21e7.wav       Snare_drum   6.195000
# ff55a1e2.wav  Acoustic_guitar  14.660000
# ff752a0c.wav         Clarinet   5.244562
# ff875923.wav            Cello  11.840000
# ffc92b01.wav            Cello   6.102437
#
# [2480 rows x 2 columns]

# %%
# how to handle class imbalance when training
#audio is different from rest data because it is sampled so frequently and we have to create
#an arbitary length of time that we need to build a sample with,
#1 sample at 10th of second, we will randomly sample with length of audio file
# we  will take that 1 second chunk out of that audio, for samples to be huge, we will take twice that value

n_samples = 2 * int(df["length"].sum()/0.1)
prob_dist = class_dist / class_dist.sum()
choices = np.random.choice(class_dist.index, p = prob_dist)
prob_dist
# Out:
# label
# Acoustic_guitar     0.145228
# Bass_drum           0.067255
# Cello               0.118294
# Clarinet            0.107023
# Double_bass         0.052644
# Flute               0.145623
# Hi-hat              0.078989
# Saxophone           0.112576
# Snare_drum          0.080441
# Violin_or_fiddle    0.091926
# Name: length, dtype: float64

# %%
def check_data() :
    if os.path.isfile(config.p_path) :
        print('loading existing data for {} model'.format(config.mode))
        with open(config.p_path , 'rb') as handle :  #'rb' is read bytes
            tmp = pickle.load(handle)
            return tmp
    else :
        return None

# %%
def build_rand_feat() :
       
    X = []
    y = []
    _min , _max = float('inf') , -float('inf')
    for _ in tqdm(range(n_samples)) :
        rand_class = np.random.choice(class_dist.index, p = prob_dist)
        file = np.random.choice(df[df.label==rand_class].index)
        rate , wav = wavfile.read('/content/drive/My Drive/Colab Notebooks/cleaner/'+file)
        label = df.at[file , 'label'] # extra
        rand_index = np.random.randint(0 , wav.shape[0] - config.step) #config.step is 10th of second
        sample = wav[rand_index : rand_index + config.step]
        X_sample = mfcc(sample,rate,numcep=config.nfeat,nfilt = config.nfilt,nfft=config.nfft)
        _min = min(np.amin(X_sample),_min)
        _max = max(np.amax(X_sample),_max)
        X.append(X_sample)
        y.append(classes.index(label))
    
    config.min = _min
    config.max = _max
    X,y = np.array(X) ,np.array(y)   
    X = (X - _min)/(_max - _min) # noramlising b/w 0 and 1
    if config.mode == 'conv' :
        X = X.reshape(X.shape[0],X.shape[1],X.shape[2],1)
    elif config.mode == 'time' :
        X = X.reshape(X.shape[0],X.shape[1],X.shape[2])
    y = to_categorical(y,num_classes = 10) # to hot encode them, as y has classes 0-num_classes, each class was represented by index

    config.data = (X,y)
    
   # with open(config.p_path, 'wb') as handle :# wb is write bytes
   #     pickle.dump(config,handle,protocol = 2)
    return X,y

# %%
def get_conv_model() :
    model = Sequential()
    model.add(Conv2D(32, (3,3) ,activation = 'relu', strides=(1,1) , padding = 'same',input_shape = input_shape))
    model.add(Conv2D(64, (3,3) ,activation = 'relu', strides=(1,1) , padding = 'same'))
    model.add(Conv2D(128, (3,3) ,activation = 'relu', strides=(1,1) , padding = 'same'))
    model.add(Conv2D(256, (3,3) ,activation = 'relu', strides=(1,1) , padding = 'same'))
    model.add(MaxPool2D((2,2)))
    model.add(Dropout(0.5))
    model.add(Flatten())
    model.add(Dense(256, activation = 'relu'))
    model.add(Dense(128, activation = 'relu'))
    model.add(Dense(10, activation = 'softmax'))
    model.summary()
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['acc'])
    return model

# %%
def get_recurrent_model() :
    model = Sequential()
    model.add(LSTM(128, return_sequences = True,input_shape = input_shape))
    model.add(LSTM(128, return_sequences = True))
    model.add(Dropout(0.5))
    model.add(TimeDistributed(Dense(64, activation = "relu")))
    model.add(TimeDistributed(Dense(32, activation = "relu")))
    model.add(TimeDistributed(Dense(16, activation = "relu")))
    model.add(TimeDistributed(Dense(8, activation = "relu")))
    model.add(Flatten())
    model.add(Dense(10, activation = 'softmax'))
    model.summary()
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['acc'])
    return model

# %%
import os

class Config :                                                 # because we have down-sampled
    def __init__(self ,mode = "conv" , nfilt = 26 , nfeat = 13, nfft = 512 , rate = 16000) :
        self.mode = mode
        self.nfilt = nfilt
        self.nfeat = nfeat
        self.nfft = nfft
        self.rate = rate
        self.step = int(rate/10)
        self.model_path = os.path.join("models",mode + ".model")
        self.p_path = os.path.join("pickles",mode + ".p")

# %%
config = Config(mode = "conv")

if config.mode == "conv" :
    X , y = build_rand_feat()
    y_flat =  np.argmax(y, axis = 1)
    input_shape = (X.shape[1] , X.shape[2] , 1)
    model = get_conv_model()
    model = get_conv_model()
    
elif config.mode == "time" :
    X,y = build_rand_feat() 
    y_flat =  np.argmax(y, axis = 1)
    input_shape = (X.shape[1] , X.shape[2]) 
    model = get_recurrent_model()
# Out:
# 100%|██████████| 313690/313690 [23:13<00:00, 225.08it/s]
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 9, 13, 32)         320
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 9, 13, 64)         18496
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 9, 13, 128)        73856
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 9, 13, 256)        295168
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 6, 256)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 4, 6, 256)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 6144)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               1573120
# _________________________________________________________________
# dense_19 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 1,995,146
# Trainable params: 1,995,146
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 9, 13, 32)         320
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 9, 13, 64)         18496
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 9, 13, 128)        73856
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 9, 13, 256)        295168
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 4, 6, 256)         0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 4, 6, 256)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 6144)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               1573120
# _________________________________________________________________
# dense_22 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_23 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 1,995,146
# Trainable params: 1,995,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
class_weight = compute_class_weight('balanced',np.unique(y_flat),y_flat)

# %%
checkpoint = ModelCheckpoint(config.model_path, monitor = 'val_acc',verbose=1, mode = 'max',
                            save_best_only = True, save_weights_only = False, period = 1)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y)

# %%
history = model.fit(x_train,y_train,epochs=50,batch_size=32,shuffle=True,validation_split = 0.1, callbacks = [checkpoint])
# Out:
# Epoch 1/50
# 6616/6617 [============================>.] - ETA: 0s - loss: 0.9652 - acc: 0.6607
# Epoch 00001: val_acc improved from -inf to 0.76691, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.9652 - acc: 0.6607 - val_loss: 0.6804 - val_acc: 0.7669
# Epoch 2/50
# 6614/6617 [============================>.] - ETA: 0s - loss: 0.6258 - acc: 0.7844
# Epoch 00002: val_acc improved from 0.76691 to 0.82535, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.6258 - acc: 0.7844 - val_loss: 0.5113 - val_acc: 0.8253
# Epoch 3/50
# 6616/6617 [============================>.] - ETA: 0s - loss: 0.5209 - acc: 0.8202
# Epoch 00003: val_acc improved from 0.82535 to 0.83300, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.5209 - acc: 0.8202 - val_loss: 0.4870 - val_acc: 0.8330
# Epoch 4/50
# 6614/6617 [============================>.] - ETA: 0s - loss: 0.4602 - acc: 0.8410
# Epoch 00004: val_acc improved from 0.83300 to 0.86046, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.4602 - acc: 0.8410 - val_loss: 0.4196 - val_acc: 0.8605
# Epoch 5/50
# 6615/6617 [============================>.] - ETA: 0s - loss: 0.4187 - acc: 0.8554
# Epoch 00005: val_acc improved from 0.86046 to 0.87810, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.4188 - acc: 0.8554 - val_loss: 0.3549 - val_acc: 0.8781
# Epoch 6/50
# 6617/6617 [==============================] - ETA: 0s - loss: 0.3849 - acc: 0.8664
# Epoch 00006: val_acc improved from 0.87810 to 0.88375, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.3849 - acc: 0.8664 - val_loss: 0.3407 - val_acc: 0.8838
# Epoch 7/50
# 6614/6617 [============================>.] - ETA: 0s - loss: 0.3632 - acc: 0.8747
# Epoch 00007: val_acc improved from 0.88375 to 0.89455, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 75s 11ms/step - loss: 0.3631 - acc: 0.8747 - val_loss: 0.3206 - val_acc: 0.8945
# Epoch 8/50
# 6614/6617 [============================>.] - ETA: 0s - loss: 0.3406 - acc: 0.8829
# Epoch 00008: val_acc did not improve from 0.89455
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.3407 - acc: 0.8828 - val_loss: 0.3443 - val_acc: 0.8879
# Epoch 9/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.3243 - acc: 0.8880
# Epoch 00009: val_acc improved from 0.89455 to 0.90067, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.3243 - acc: 0.8880 - val_loss: 0.2961 - val_acc: 0.9007
# Epoch 10/50
# 6614/6617 [============================>.] - ETA: 0s - loss: 0.3124 - acc: 0.8929
# Epoch 00010: val_acc improved from 0.90067 to 0.90607, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.3124 - acc: 0.8929 - val_loss: 0.2855 - val_acc: 0.9061
# Epoch 11/50
# 6615/6617 [============================>.] - ETA: 0s - loss: 0.2970 - acc: 0.8977
# Epoch 00011: val_acc improved from 0.90607 to 0.91100, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.2971 - acc: 0.8977 - val_loss: 0.2753 - val_acc: 0.9110
# Epoch 12/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.2869 - acc: 0.9006
# Epoch 00012: val_acc did not improve from 0.91100
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.2869 - acc: 0.9006 - val_loss: 0.2748 - val_acc: 0.9086
# Epoch 13/50
# 6616/6617 [============================>.] - ETA: 0s - loss: 0.2812 - acc: 0.9029
# Epoch 00013: val_acc improved from 0.91100 to 0.91537, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.2812 - acc: 0.9028 - val_loss: 0.2606 - val_acc: 0.9154
# Epoch 14/50
# 6614/6617 [============================>.] - ETA: 0s - loss: 0.2712 - acc: 0.9060
# Epoch 00014: val_acc improved from 0.91537 to 0.91635, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.2712 - acc: 0.9060 - val_loss: 0.2600 - val_acc: 0.9164
# Epoch 15/50
# 6616/6617 [============================>.] - ETA: 0s - loss: 0.2624 - acc: 0.9092
# Epoch 00015: val_acc did not improve from 0.91635
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.2624 - acc: 0.9092 - val_loss: 0.2684 - val_acc: 0.9130
# Epoch 16/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.2551 - acc: 0.9120
# Epoch 00016: val_acc did not improve from 0.91635
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.2551 - acc: 0.9120 - val_loss: 0.2705 - val_acc: 0.9139
# Epoch 17/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.2518 - acc: 0.9127
# Epoch 00017: val_acc did not improve from 0.91635
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.2517 - acc: 0.9127 - val_loss: 0.3062 - val_acc: 0.9022
# Epoch 18/50
# 6614/6617 [============================>.] - ETA: 0s - loss: 0.2459 - acc: 0.9153
# Epoch 00018: val_acc did not improve from 0.91635
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.2459 - acc: 0.9152 - val_loss: 0.2972 - val_acc: 0.9045
# Epoch 19/50
# 6615/6617 [============================>.] - ETA: 0s - loss: 0.2376 - acc: 0.9181
# Epoch 00019: val_acc improved from 0.91635 to 0.92375, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.2375 - acc: 0.9181 - val_loss: 0.2363 - val_acc: 0.9237
# Epoch 20/50
# 6617/6617 [==============================] - ETA: 0s - loss: 0.2324 - acc: 0.9196
# Epoch 00020: val_acc improved from 0.92375 to 0.92464, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 75s 11ms/step - loss: 0.2324 - acc: 0.9196 - val_loss: 0.2376 - val_acc: 0.9246
# Epoch 21/50
# 6616/6617 [============================>.] - ETA: 0s - loss: 0.2276 - acc: 0.9222
# Epoch 00021: val_acc did not improve from 0.92464
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.2276 - acc: 0.9222 - val_loss: 0.2426 - val_acc: 0.9237
# Epoch 22/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.2251 - acc: 0.9226
# Epoch 00022: val_acc did not improve from 0.92464
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.2251 - acc: 0.9226 - val_loss: 0.2983 - val_acc: 0.9039
# Epoch 23/50
# 6615/6617 [============================>.] - ETA: 0s - loss: 0.2194 - acc: 0.9241
# Epoch 00023: val_acc improved from 0.92464 to 0.93127, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.2194 - acc: 0.9241 - val_loss: 0.2254 - val_acc: 0.9313
# Epoch 24/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.2172 - acc: 0.9253
# Epoch 00024: val_acc did not improve from 0.93127
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.2172 - acc: 0.9253 - val_loss: 0.2350 - val_acc: 0.9277
# Epoch 25/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.2174 - acc: 0.9260
# Epoch 00025: val_acc did not improve from 0.93127
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.2174 - acc: 0.9260 - val_loss: 0.2323 - val_acc: 0.9271
# Epoch 26/50
# 6617/6617 [==============================] - ETA: 0s - loss: 0.2080 - acc: 0.9284
# Epoch 00026: val_acc did not improve from 0.93127
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.2080 - acc: 0.9284 - val_loss: 0.2476 - val_acc: 0.9244
# Epoch 27/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.2096 - acc: 0.9282
# Epoch 00027: val_acc did not improve from 0.93127
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.2096 - acc: 0.9282 - val_loss: 0.2670 - val_acc: 0.9190
# Epoch 28/50
# 6615/6617 [============================>.] - ETA: 0s - loss: 0.2051 - acc: 0.9299
# Epoch 00028: val_acc did not improve from 0.93127
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.2052 - acc: 0.9299 - val_loss: 0.2324 - val_acc: 0.9301
# Epoch 29/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.1993 - acc: 0.9315
# Epoch 00029: val_acc did not improve from 0.93127
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.1993 - acc: 0.9315 - val_loss: 0.2327 - val_acc: 0.9278
# Epoch 30/50
# 6615/6617 [============================>.] - ETA: 0s - loss: 0.1987 - acc: 0.9319
# Epoch 00030: val_acc improved from 0.93127 to 0.93340, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 75s 11ms/step - loss: 0.1986 - acc: 0.9319 - val_loss: 0.2255 - val_acc: 0.9334
# Epoch 31/50
# 6617/6617 [==============================] - ETA: 0s - loss: 0.1967 - acc: 0.9330
# Epoch 00031: val_acc did not improve from 0.93340
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.1967 - acc: 0.9330 - val_loss: 0.3024 - val_acc: 0.9108
# Epoch 32/50
# 6616/6617 [============================>.] - ETA: 0s - loss: 0.1954 - acc: 0.9333
# Epoch 00032: val_acc did not improve from 0.93340
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.1954 - acc: 0.9333 - val_loss: 0.2333 - val_acc: 0.9303
# Epoch 33/50
# 6615/6617 [============================>.] - ETA: 0s - loss: 0.1924 - acc: 0.9346
# Epoch 00033: val_acc did not improve from 0.93340
# 6617/6617 [==============================] - 75s 11ms/step - loss: 0.1923 - acc: 0.9346 - val_loss: 0.2455 - val_acc: 0.9254
# Epoch 34/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.1907 - acc: 0.9353
# Epoch 00034: val_acc improved from 0.93340 to 0.93573, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 75s 11ms/step - loss: 0.1907 - acc: 0.9353 - val_loss: 0.2240 - val_acc: 0.9357
# Epoch 35/50
# 6614/6617 [============================>.] - ETA: 0s - loss: 0.1854 - acc: 0.9367
# Epoch 00035: val_acc did not improve from 0.93573
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.1854 - acc: 0.9367 - val_loss: 0.2509 - val_acc: 0.9276
# Epoch 36/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.1849 - acc: 0.9367
# Epoch 00036: val_acc did not improve from 0.93573
# 6617/6617 [==============================] - 75s 11ms/step - loss: 0.1848 - acc: 0.9367 - val_loss: 0.2243 - val_acc: 0.9346
# Epoch 37/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.1849 - acc: 0.9374
# Epoch 00037: val_acc improved from 0.93573 to 0.93828, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 76s 12ms/step - loss: 0.1848 - acc: 0.9374 - val_loss: 0.2140 - val_acc: 0.9383
# Epoch 38/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.1818 - acc: 0.9382
# Epoch 00038: val_acc did not improve from 0.93828
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.1817 - acc: 0.9382 - val_loss: 0.2225 - val_acc: 0.9352
# Epoch 39/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.1805 - acc: 0.9389
# Epoch 00039: val_acc did not improve from 0.93828
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.1804 - acc: 0.9389 - val_loss: 0.2217 - val_acc: 0.9357
# Epoch 40/50
# 6616/6617 [============================>.] - ETA: 0s - loss: 0.1778 - acc: 0.9398
# Epoch 00040: val_acc did not improve from 0.93828
# 6617/6617 [==============================] - 75s 11ms/step - loss: 0.1778 - acc: 0.9398 - val_loss: 0.2196 - val_acc: 0.9366
# Epoch 41/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.1770 - acc: 0.9403
# Epoch 00041: val_acc did not improve from 0.93828
# 6617/6617 [==============================] - 75s 11ms/step - loss: 0.1770 - acc: 0.9403 - val_loss: 0.2320 - val_acc: 0.9342
# Epoch 42/50
# 6617/6617 [==============================] - ETA: 0s - loss: 0.1734 - acc: 0.9411
# Epoch 00042: val_acc did not improve from 0.93828
# 6617/6617 [==============================] - 75s 11ms/step - loss: 0.1734 - acc: 0.9411 - val_loss: 0.2737 - val_acc: 0.9232
# Epoch 43/50
# 6614/6617 [============================>.] - ETA: 0s - loss: 0.1765 - acc: 0.9404
# Epoch 00043: val_acc did not improve from 0.93828
# 6617/6617 [==============================] - 75s 11ms/step - loss: 0.1766 - acc: 0.9403 - val_loss: 0.2247 - val_acc: 0.9356
# Epoch 44/50
# 6617/6617 [==============================] - ETA: 0s - loss: 0.1720 - acc: 0.9418
# Epoch 00044: val_acc did not improve from 0.93828
# 6617/6617 [==============================] - 75s 11ms/step - loss: 0.1720 - acc: 0.9418 - val_loss: 0.2332 - val_acc: 0.9326
# Epoch 45/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.1716 - acc: 0.9421
# Epoch 00045: val_acc did not improve from 0.93828
# 6617/6617 [==============================] - 75s 11ms/step - loss: 0.1716 - acc: 0.9421 - val_loss: 0.2218 - val_acc: 0.9381
# Epoch 46/50
# 6616/6617 [============================>.] - ETA: 0s - loss: 0.1718 - acc: 0.9421
# Epoch 00046: val_acc did not improve from 0.93828
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.1718 - acc: 0.9421 - val_loss: 0.2252 - val_acc: 0.9368
# Epoch 47/50
# 6615/6617 [============================>.] - ETA: 0s - loss: 0.1712 - acc: 0.9428
# Epoch 00047: val_acc improved from 0.93828 to 0.94096, saving model to models/conv.model
# INFO:tensorflow:Assets written to: models/conv.model/assets
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.1712 - acc: 0.9428 - val_loss: 0.2105 - val_acc: 0.9410
# Epoch 48/50
# 6613/6617 [============================>.] - ETA: 0s - loss: 0.1694 - acc: 0.9429
# Epoch 00048: val_acc did not improve from 0.94096
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.1695 - acc: 0.9429 - val_loss: 0.2379 - val_acc: 0.9325
# Epoch 49/50
# 6616/6617 [============================>.] - ETA: 0s - loss: 0.1670 - acc: 0.9440
# Epoch 00049: val_acc did not improve from 0.94096
# 6617/6617 [==============================] - 74s 11ms/step - loss: 0.1670 - acc: 0.9440 - val_loss: 0.2467 - val_acc: 0.9334
# Epoch 50/50
# 6617/6617 [==============================] - ETA: 0s - loss: 0.1660 - acc: 0.9442
# Epoch 00050: val_acc did not improve from 0.94096
# 6617/6617 [==============================] - 73s 11ms/step - loss: 0.1660 - acc: 0.9442 - val_loss: 0.2438 - val_acc: 0.9320

# %%
y_pred = model.predict(x_test)

# %%
y_pred = (y_pred > 0.5) 
y_pred
# Out:
# array([[ True, False, False, ..., False, False, False],
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [ True, False, False, ..., False, False, False],
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
y_test = (y_test > 0.5) 
y_test
# Out:
# array([[ True, False, False, ..., False, False, False],
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [ True, False, False, ..., False, False, False],
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93     11534
#            1       0.93      0.95      0.94      5372
#            2       0.91      0.91      0.91      9244
#            3       0.96      0.95      0.95      8168
#            4       0.89      0.84      0.86      4164
#            5       0.94      0.94      0.94     11504
#            6       0.97      0.97      0.97      6252
#            7       0.96      0.91      0.93      8694
#            8       0.97      0.92      0.95      6318
#            9       0.93      0.93      0.93      7173
#
#    micro avg       0.94      0.93      0.93     78423
#    macro avg       0.94      0.92      0.93     78423
# weighted avg       0.94      0.93      0.93     78423
#  samples avg       0.93      0.93      0.93     78423
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
